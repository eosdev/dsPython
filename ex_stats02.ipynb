# %%
airbnb_CDBD= pd.read_csv('C:/Users/Eden/Documents/PUC-MG - Inteligência Artifical e Aprendizado de Máquina/EG/Dados airbnb_CDBD.csv', sep=';', encoding='latin-1', low_memory = False, 
                                dtype={'ID':str,
                                 'ID da hospedagem':str,
                                  'Nome da hospedagem':str,
                                  'ID do Hospede':str,
                                  'Nome do Hospede':str,
                                  'Grupo de vizinhança':str,
                                  'latitude': float,
                                  'longitude': float,
                                  'Tipo de hospedagem': str,
                                  'Preço': float,
                                  'locação mínima':float,
                                  'Número de avaliações':float,
                                  'Taxa mesal de ocupação':float,
                                  'Número máximo de hóspedes':float,
                                  'Disponibilidade anual':float})

# %%
airbnb_CDBD.head()
# Out:
#    ID ID da hospedagem                         Nome da hospedagem  \
# 0   1             2539         Clean & quiet apt home by the park
# 1   2             2595                      Skylit Midtown Castle
# 2   6             5099  Large Cozy 1 BR Apartment In Midtown East
# 3  23             8025                   CBG Helps Haiti Room#2.5
# 4  24             8110                      CBG Helps Haiti Rm #2
#
#   ID do Hospede Nome do Hospede Grupo de vizinhança   latitude  longitude  \
# 0          2787            John            Brooklyn  4064749.0 -7397237.0
# 1          2845        Jennifer           Manhattan  4075362.0 -7398377.0
# 2          7322           Chris           Manhattan  4074767.0   -73975.0
# 3         22486           Lisel            Brooklyn  4067989.0 -7397798.0
# 4         22486           Lisel            Brooklyn  4068001.0 -7397865.0
#
#   Tipo de hospedagem  Preço  locação mínima  Número de avaliações  \
# ...

# %%
airbnb_CDBD.tail()
# Out:
#       ID ID da hospedagem                  Nome da hospedagem ID do Hospede  \
# 206  589           222054               CBG Helps Haiti Rm #3         22486
# 207  590           222304     BEST DEAL IN CHELSEA 1 bdrm NYC       1153993
# 208  591           223930                    Lovely Apartment       1164642
# 209  592           224004    Artsy Loft-like Harlem Apartment       1165231
# 210  593           224006  Harlem/Manhattan Classic Apartment       1165231
#
#     Nome do Hospede Grupo de vizinhança   latitude  longitude  \
# 206           Lisel            Brooklyn  4068012.0 -7397847.0
# 207           Anton           Manhattan  4074233.0 -7399865.0
# 208        Rosalynn            Brooklyn  4067424.0 -7396665.0
# 209         Deirdre           Manhattan  4080486.0 -7395298.0
# 210         Deirdre           Manhattan  4080307.0 -7395048.0
#
#     Tipo de hospedagem  Preço  locação mínima  Número de avaliações  \
# ...

# %%
corr = airbnb_CDBD.corr()
corr
# Out:
#                            latitude  longitude     Preço  locação mínima  \
# latitude                   1.000000   0.036817  0.001720       -0.070629
# longitude                  0.036817   1.000000  0.034545       -0.002152
# Preço                      0.001720   0.034545  1.000000        0.184835
# locação mínima            -0.070629  -0.002152  0.184835        1.000000
# Número de avaliações       0.000698  -0.038546 -0.967792       -0.188091
# Taxa mesal de ocupação     0.018892  -0.046794 -0.954519       -0.169307
# Número máximo de hóspedes  0.042136  -0.058383  0.086738       -0.116842
# Disponibilidade anual      0.047530   0.098461  0.065883       -0.049531
#
#                            Número de avaliações  Taxa mesal de ocupação  \
# latitude                               0.000698                0.018892
# longitude                             -0.038546               -0.046794
# Preço                                 -0.967792               -0.954519
# ...

# %%
airbnb_CDBD.shape
# Out:
# (211, 15)

# %%
airbnb_CDBD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 15 columns):
# ID                           211 non-null object
# ID da hospedagem             211 non-null object
# Nome da hospedagem           211 non-null object
# ID do Hospede                211 non-null object
# Nome do Hospede              211 non-null object
# Grupo de vizinhança          211 non-null object
# latitude                     209 non-null float64
# longitude                    211 non-null float64
# Tipo de hospedagem           211 non-null object
# Preço                        211 non-null float64
# locação mínima               211 non-null float64
# Número de avaliações         211 non-null float64
# Taxa mesal de ocupação       211 non-null float64
# Número máximo de hóspedes    211 non-null float64
# Disponibilidade anual        211 non-null float64
# dtypes: float64(8), object(7)
# memory usage: 24.8+ KB

# %%
#função que verifica se existem colunas com valores vazios
for col in (airbnb_CDBD):
    if(airbnb_CDBD[col].isnull().any()):
        print(col)
# Out:
# latitude

# %%
#Substituir os valores vazios
airbnb_CDBD=airbnb_CDBD.fillna(0)

# %%
airbnb_CDBD['latitude'].head()
# Out:
# 0    4064749.0
# 1    4075362.0
# 2    4074767.0
# 3    4067989.0
# 4    4068001.0
# Name: latitude, dtype: float64

# %%
#Contagem de número de clientes que se hospedaram nos grupos de vizinhança
airbnb_CDBD[['Grupo de vizinhança', 'ID do Hospede']].groupby(['Grupo de vizinhança'], as_index=False).count().sort_values(by='ID do Hospede',ascending=False)
# Out:
#   Grupo de vizinhança  ID do Hospede
# 1           Manhattan            107
# 0            Brooklyn            104

# %%
#Contagem de número de clientes que se hospedaram nos grupos de vizinhança
airbnb_CDBD[['Tipo de hospedagem', 'ID do Hospede']].groupby(['Tipo de hospedagem'], as_index=False).count().sort_values(by='ID do Hospede',ascending=False)
# Out:
#   Tipo de hospedagem  ID do Hospede
# 0    Ap/Casa inteira            128
# 1   Quarto Privativo             83

# %%
#Estatísticas descritivas
print('Média: {}'.format(round(st.mean(airbnb_CDBD['Disponibilidade anual']),2)))
print('Moda: {}'.format(round(st.mode(airbnb_CDBD['Disponibilidade anual']),2)))
print('Mediana: {}'.format(round(st.median(airbnb_CDBD['Disponibilidade anual']),2)))
print('Variância: {}'.format(round(st.variance(airbnb_CDBD['Disponibilidade anual']),2)))
print('Desvio Padrão: {}'.format(round(st.stdev(airbnb_CDBD['Disponibilidade anual']),2)))
# Out:
# Média: 204.64
# Moda: 365.0
# Mediana: 223.0
# Variância: 11680.95
# Desvio Padrão: 108.08

# %%
#Box-plot de preço
fig = plt.figure()
fig.suptitle('BoxPlot Preço - AirBNB')
sns.boxplot(data=airbnb_CDBD['Preço'], orient="v", palette="Set2")

# %%
# Histograma da distribuição de preço
fig = plt.figure()
fig.suptitle('Histograma de  Preço - AirBNB')
sns.distplot( a=airbnb_CDBD['Preço'],bins=20, kde=True,
kde_kws={"color": "r", "alpha":0.3, "linewidth": 5, "shade":True })

# %%
#Box-plot de locação mínima
fig = plt.figure()
fig.suptitle('BoxPlot Locação Mínima - AirBNB')
sns.boxplot(data=airbnb_CDBD['locação mínima'], orient="v", palette="Set2")

# %%
# Histograma da distribuição de locação mínima
fig = plt.figure()
fig.suptitle('Histograma de Locação mínima - AirBNB')
sns.distplot( a=airbnb_CDBD['locação mínima'],bins=20, kde=True,
kde_kws={"color": "r", "alpha":0.3, "linewidth": 5, "shade":True })

# %%
#Box-plot de Número de avaliações
fig = plt.figure()
fig.suptitle('BoxPlot Número de avaliações - AirBNB')
sns.boxplot(data=airbnb_CDBD['Número de avaliações'], orient="v", palette="Set2")

# %%
# Histograma da distribuição de Número de avaliações
fig = plt.figure()
fig.suptitle('Histograma de Número de avaliações - AirBNB')
sns.distplot( a=airbnb_CDBD['Número de avaliações'],bins=20, kde=True,
kde_kws={"color": "r", "alpha":0.3, "linewidth": 5, "shade":True })

# %%
#Box-plot de locação mínima
fig = plt.figure()
fig.suptitle('BoxPlot Taxa Mensal de Ocupação - AirBNB')
sns.boxplot(data=airbnb_CDBD['Taxa mesal de ocupação'], orient="v", palette="Set2")

# %%
# Histograma da distribuição de locação mínima
fig = plt.figure()
fig.suptitle('Histograma de Taxa Mensal de Ocupação - AirBNB')
sns.distplot( a=airbnb_CDBD['Taxa mesal de ocupação'],bins=20, kde=True,
kde_kws={"color": "r", "alpha":0.3, "linewidth": 5, "shade":True })

# %%
#Box-plot de Número máximo de hóspedes
fig = plt.figure()
fig.suptitle('BoxPlot Número máximo de hóspedes - AirBNB')
sns.boxplot(data=airbnb_CDBD['Número máximo de hóspedes'], orient="v", palette="Set2")

# %%
# Histograma da distribuição de locação mínima
fig = plt.figure()
fig.suptitle('Histograma Número máximo de hóspedes - AirBNB')
sns.distplot( a=airbnb_CDBD['Número máximo de hóspedes'],bins=20, kde=True,
kde_kws={"color": "r", "alpha":0.3, "linewidth": 5, "shade":True })

# %%
#Box-plot disponibiliade anual
fig = plt.figure()
fig.suptitle('BoxPlot Disponibilidade anual - AirBNB')
sns.boxplot(data=airbnb_CDBD['Disponibilidade anual'], orient="v", palette="Set2")

# %%
# Histograma de disponibiliade anual
fig = plt.figure()
fig.suptitle('Histograma Disponibilidade anual - AirBNB')
sns.distplot( a=airbnb_CDBD['Disponibilidade anual'],bins=20, kde=True,
kde_kws={"color": "r", "alpha":0.3, "linewidth": 5, "shade":True })

# %%
#Taxa de ocupação por grupo de vizinhaça
airbnb_CDBD[['Grupo de vizinhança', 'Taxa mesal de ocupação']].groupby(['Grupo de vizinhança'], as_index=False).mean().sort_values(by='Taxa mesal de ocupação',ascending=False)
# Out:
#   Grupo de vizinhança  Taxa mesal de ocupação
# 1           Manhattan                0.395607
# 0            Brooklyn                0.366250

# %%
#Taxa de ocupação por tipo de hospedagem
airbnb_CDBD[['Tipo de hospedagem', 'Taxa mesal de ocupação']].groupby(['Tipo de hospedagem'], as_index=False).mean().sort_values(by='Taxa mesal de ocupação',ascending=False)
# Out:
#   Tipo de hospedagem  Taxa mesal de ocupação
# 0    Ap/Casa inteira                0.385859
# 1   Quarto Privativo                0.373855

# %%
#Correlação de multiplas variáveis
# %matplotlib inline
import seaborn as sns
fig = plt.figure()
fig.suptitle('Correlação AirBNB')
#plt.figure(figsize=(5,5))
sns.heatmap(corr, annot = True, linewidth=0.2)

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
sns.jointplot(x=airbnb_CDBD["Taxa mesal de ocupação"], y=airbnb_CDBD["Preço"], kind='scatter')
#sns.jointplot(x=airbnb_CDBD["Taxa mesal de ocupação"], y=airbnb_CDBD["Preço"], kind='hex')
#sns.jointplot(x=airbnb_CDBD["Taxa mesal de ocupação"], y=airbnb_CDBD["Preço"], kind='kde')

# %%
#Gráfico de dispersão Preço versus Taxa mensal de ocupação
j=sns.jointplot(x=airbnb_CDBD["Taxa mesal de ocupação"], y=airbnb_CDBD["Preço"], kind='scatter', s=100, color='b', edgecolor="skyblue", linewidth=1.5).annotate(stats.pearsonr)
#j.annotate(stats.pearsonr)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
#Gráfico de dispersão Taxa mensal de ocupação versus Número de avaliações
j=sns.jointplot(x=airbnb_CDBD["Taxa mesal de ocupação"], y=airbnb_CDBD["Número de avaliações"], kind='scatter', s=100, color='b', edgecolor="skyblue", linewidth=1.5).annotate(stats.pearsonr)
#j.annotate(stats.pearsonr)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
#Criando variáveis para a equação de regressão linear múltipla
x = airbnb_CDBD[["Taxa mesal de ocupação","Preço"]] 
y = airbnb_CDBD["Número de avaliações"]

# Argumentos para o modelo de regressão
model = sm.OLS(y, x).fit()
predictions = model.predict(x) # faça as previsões pelo modelo
x = sm.add_constant(x) #constante

# Imprimir estatísticas
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Número de avaliações   R-squared:                       0.982
# Model:                              OLS   Adj. R-squared:                  0.982
# Method:                   Least Squares   F-statistic:                     5737.
# Date:                  Sun, 24 Nov 2019   Prob (F-statistic):          2.49e-183
# Time:                          01:04:21   Log-Likelihood:                -674.11
# No. Observations:                   211   AIC:                             1352.
# Df Residuals:                       209   BIC:                             1359.
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
#Salva os resultados da regressão elaborada
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 7))
#plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 12}) old approach
plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()
plt.savefig('output.png')

# %%
#airbnb_CDBD[(airbnb_CDBD.Preço >= 100)] #& (airbnb_CDBD.Taxa mesal de ocupação <= 0.3)]
# Out:
#       ID ID da hospedagem                                 Nome da hospedagem  \
# 0      1             2539                 Clean & quiet apt home by the park
# 9     42            12299                Beautiful Sunny Park Slope Brooklyn
# 16    55            14322                Beautiful Apartment in Manhattan!!!
# 17    57            14991                 Great Location. Manhattan Bedroom!
# 18    60            15341      **Bright Nolita Apt w Doorman/Elevators/Gym**
# 23    73            17092                        Cool Room in Hell's Kitchen
# 24    76            18127             Charming East Village One Bedroom Flat
# 28    84            19282                    Sunny. Spacious Top Floor Haven
# 32    93            20755  Large Parlor Room. Landmark Home 1 block to PRATT
# 33    94            20853                   2-bed brownstone duplex + garden
# 35    98            21644                          Upper Manhattan. New York
# ...

# %%
import os
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from pandas import read_excel
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st
import scipy.stats as stats
import statsmodels.api as sm
